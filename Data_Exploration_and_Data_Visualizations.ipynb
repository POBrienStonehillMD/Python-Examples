# %% [markdown]
# ## The Data
#
# You will be working with a famous titanic data set in the first part of this project.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %% [markdown]
# **Recreate the plots below using the titanic dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Pay attention to the x and y labels.**
#
# Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!

# %%
# CODE HERE
sns.jointplot(x='fare', y='age', data=titanic)

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE
# bin size is 30.

sns.distplot(titanic['fare'], bins=30, color='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# DO NOT PUT YOUR CODE HERE!!!
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# CODE HERE

sns.boxplot(x='class', y='age', data=titanic, palette='pastel')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

sns.violinplot(x='class', y='age', data=titanic, palette='Set2')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

sns.countplot(x='sex', data=titanic)

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

#you should use titanic.corr() for the following graph. You can use any cmap.

sns.heatmap(titanic.corr(), cmap='coolwarm',)
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
# DO NOT PUT YOUR CODE HERE!!!
# Out:
# Text(0.5, 1.0, 'titanic.corr()')

# %%
# CODE HERE


g1 = sns.FacetGrid(data=titanic, col='sex')
g1.map(plt.hist, 'age')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %% [markdown]
# ## Tumor Analysis
#
# In the second part of data project you will focus on cancer data set.

# %%
# import libraries 
import pandas as pd # Import Pandas for data manipulation using dataframes
import numpy as np # Import Numpy for data statistical analysis 

# Import Cancer data drom the Sklearn library
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()

# Create a dataFrame named df_cancer with input/output data
df_cancer = pd.DataFrame(np.c_[cancer['data'], cancer['target']], columns = np.append(cancer['feature_names'], ['target']))

# Check out the head of the dataframe
df_cancer.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890     0.0
# 1        20.57         17.77  ...                  0.08902     0.0
# 2        19.69         21.25  ...                  0.08758     0.0
# 3        11.42         20.38  ...                  0.17300     0.0
# 4        20.29         14.34  ...                  0.07678     0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# **Recreate the plots below using the df_cancer dataframe. There are very few hints since most of the plots can be done with just one or two lines of code and a hint would basically give away the solution. Pay attention to the x and y labels.**
#
# Note! In order to not lose the plot image, make sure you don't code in the cell that is directly above the plot, there is an extra cell above that one which won't overwrite that plot!

# %%
# CODE HERE

sns.scatterplot(x='mean area', y='mean smoothness', data=df_cancer, hue='target')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

sns.scatterplot(x='mean radius', y='mean area', data=df_cancer, hue='target')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

sns.countplot(x='target', data=df_cancer)

# %%
# DO NOT PUT YOUR CODE HERE!!!
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# CODE HERE

sns.pairplot(data=df_cancer, x_vars=['mean radius', 'mean texture','mean area', 'mean perimeter', 'mean smoothness'], y_vars=['mean radius', 'mean texture','mean area', 'mean perimeter', 'mean smoothness'], hue='target')

# %%
# DO NOT PUT YOUR CODE HERE!!!

# %%
# CODE HERE

fig = plt.figure(figsize=(20,10), dpi=72)
sns.heatmap(df_cancer.corr(), annot=True)
fig.savefig('cancerdataheatmep.png')

# %%
# DO NOT PUT YOUR CODE HERE!!!
